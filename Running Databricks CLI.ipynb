# %%
# %sh curl -fsSL https://raw.githubusercontent.com/databricks/setup-cli/main/install.sh | sh

# %%
# %%sh
# /home/spark-6cb77a0c-4712-4ca9-a828-fd/bin/databricks -v
